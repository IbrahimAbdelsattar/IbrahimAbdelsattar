# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# # Pandas DataFrame exercises

# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
# Print the pandas version and the configuration
print(pd.__version__)
# Out:
# 2.2.3

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame creation

# %% [markdown]
# ### Create an empty pandas DataFrame

# %%
# your code goes here
df=pd.DataFrame(
    data=[None],
    index=[None],
    columns=[None]
)

# %% [markdown]
# <img width=700 src="https://cdn.dribbble.com/users/4678/screenshots/1986600/avengers.png"></img>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a `marvel_df` pandas DataFrame with the given marvel data

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]

]

# %%
# your code goes here
column=['Name','Gender','first_appearance']
marvel_df=pd.DataFrame(data=marvel_data,columns=column)
marvel_df.index=marvel_df['Name']
marvel_df
# Out:
#                               Name  Gender  first_appearance
# Name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# Doctor Strange      Doctor Strange    male              1963
# Hank Pym                  Hank Pym    male              1962
# Scarlet Witch        Scarlet Witch  female              1964
# Wasp                          Wasp  female              1963
# Black Widow            Black Widow  female              1964
# Vision                      Vision    male              1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop the name column as it's now the index

# %%
# your code goes here
marvel_df.drop(('Name'),axis=1, inplace=True)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop 'Namor' and 'Hank Pym' rows

# %%
marvel_df
# Out:
#                   Gender  first_appearance
# Name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame selection, slicing and indexation

# %% [markdown]
# ### Show the first 5 elements on `marvel_df`

# %%
pd.isnull(marvel_df)
# Out:
#      Name  Gender  first_appearance  (Vision, first_appearance)  years_since
# 0   False   False             False                       False        False
# 1   False   False             False                       False        False
# 2   False   False             False                       False        False
# 3   False   False             False                       False        False
# 4   False   False             False                       False        False
# 5   False   False             False                       False        False
# 6   False   False             False                       False        False
# 7   False   False             False                       False        False
# 8   False   False             False                       False        False
# 9   False   False             False                       False        False
# 10  False   False             False                       False        False
# 11  False   False             False                       False        False
# 12  False   False             False                       False        False
# 13  False   False             False                       False        False
# 14  False   False             False                       False        False
# 15  False   False             False                       False        False
# 16  False   False             False                       False        False
# 17  False   False             False                       False        False
# 18  False   False             False                       False        False
# 19  False   False             False                       False        False

# %%
# your code goes here
marvel_df.iloc[:5]
# Out:
#                 Gender  first_appearance
# Name
# Spider-Man        male              1962
# Captain America   male              1941
# Wolverine         male              1974
# Iron Man          male              1963
# Thor              male              1963

# %%
#marvel_df.loc[['Spider-Man', 'Captain America', 'Wolverine', 'Iron Man', 'Thor'], :] # bad!
#marvel_df.loc['Spider-Man': 'Thor', :]
#marvel_df.iloc[0:5, :]
#marvel_df.iloc[0:5,]
marvel_df.iloc[:5,]
#marvel_df.head()
# Out:
#                 Gender  first_appearance
# Name
# Spider-Man        male              1962
# Captain America   male              1941
# Wolverine         male              1974
# Iron Man          male              1963
# Thor              male              1963

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the last 5 elements on `marvel_df`

# %%
# your code goes here
marvel_df.iloc[-5:]
# Out:
#                Gender  first_appearance
# Name
# Hank Pym         male              1962
# Scarlet Witch  female              1964
# Wasp           female              1963
# Black Widow    female              1964
# Vision           male              1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show just the sex of the first 5 elements on `marvel_df`

# %%
# your code goes here
marvel_df.iloc[:5].Gender.to_frame()
# Out:
#                 Gender
# Name
# Spider-Man        male
# Captain America   male
# Wolverine         male
# Iron Man          male
# Thor              male

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first_appearance of all middle elements on `marvel_df`

# %%
# your code goes here
marvel_df[1:-1].first_appearance.to_frame()
# Out:
#                   first_appearance
# Name
# Captain America               1941
# Wolverine                     1974
# Iron Man                      1963
# Thor                          1963
# Thing                         1961
# Mister Fantastic              1961
# Hulk                          1962
# Beast                         1963
# Invisible Woman               1961
# Storm                         1975
# Namor                         1939
# Hawkeye                       1964
# Daredevil                     1964
# Doctor Strange                1963
# Hank Pym                      1962
# Scarlet Witch                 1964
# Wasp                          1963
# Black Widow                   1964

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first and last elements on `marvel_df`

# %%
# your code goes here
marvel_df.iloc[[1,-1]]
# Out:
#                 Gender  first_appearance
# Name
# Captain America   male              1941
# Vision            male              1968

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame manipulation and operations

# %% [markdown]
# ### Modify the `first_appearance` of 'Vision' to year 1964

# %%
# your code goes here
marvel_df['Vision','first_appearance']=1964
marvel_df
# Out:
#                   Gender  first_appearance  (Vision, first_appearance)
# Name
# Spider-Man          male              1962                        1964
# Captain America     male              1941                        1964
# Wolverine           male              1974                        1964
# Iron Man            male              1963                        1964
# Thor                male              1963                        1964
# Thing               male              1961                        1964
# Mister Fantastic    male              1961                        1964
# Hulk                male              1962                        1964
# Beast               male              1963                        1964
# Invisible Woman   female              1961                        1964
# Storm             female              1975                        1964
# Namor               male              1939                        1964
# Hawkeye             male              1964                        1964
# Daredevil           male              1964                        1964
# Doctor Strange      male              1963                        1964
# Hank Pym            male              1962                        1964
# Scarlet Witch     female              1964                        1964
# Wasp              female              1963                        1964
# Black Widow       female              1964                        1964
# Vision              male              1968                        1964

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add a new column to `marvel_df` called 'years_since' with the years since `first_appearance`

# %%
# your code goes here
marvel_df['years_since']=2025-marvel_df['first_appearance']
marvel_df
# Out:
#                   Gender  first_appearance  (Vision, first_appearance)  \
# Name
# Spider-Man          male              1962                        1964
# Captain America     male              1941                        1964
# Wolverine           male              1974                        1964
# Iron Man            male              1963                        1964
# Thor                male              1963                        1964
# Thing               male              1961                        1964
# Mister Fantastic    male              1961                        1964
# Hulk                male              1962                        1964
# Beast               male              1963                        1964
# Invisible Woman   female              1961                        1964
# Storm             female              1975                        1964
# Namor               male              1939                        1964
# Hawkeye             male              1964                        1964
# Daredevil           male              1964                        1964
# Doctor Strange      male              1963                        1964
# Hank Pym            male              1962                        1964
# Scarlet Witch     female              1964                        1964
# Wasp              female              1963                        1964
# Black Widow       female              1964                        1964
# Vision              male              1968                        1964
#
#                   years_since
# Name
# Spider-Man                 63
# Captain America            84
# Wolverine                  51
# Iron Man                   62
# Thor                       62
# Thing                      64
# Mister Fantastic           64
# Hulk                       63
# Beast                      62
# Invisible Woman            64
# Storm                      50
# Namor                      86
# Hawkeye                    61
# Daredevil                  61
# Doctor Strange             62
# Hank Pym                   63
# Scarlet Witch              61
# Wasp                       62
# Black Widow                61
# Vision                     57

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame boolean arrays (also called masks)

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, make a mask showing the female characters

# %%
# your code goes here
mask=marvel_df['Gender']=='female'
mask.to_frame()
# Out:
#                   Gender
# Name
# Spider-Man         False
# Captain America    False
# Wolverine          False
# Iron Man           False
# Thor               False
# Thing              False
# Mister Fantastic   False
# Hulk               False
# Beast              False
# Invisible Woman     True
# Storm               True
# Namor              False
# Hawkeye            False
# Daredevil          False
# Doctor Strange     False
# Hank Pym           False
# Scarlet Witch       True
# Wasp                True
# Black Widow         True
# Vision             False

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the male characters

# %%
# your code goes here
mask=marvel_df['Gender']=='male'
marvel_df[mask]
# Out:
#                  Gender  first_appearance  (Vision, first_appearance)  \
# Name
# Spider-Man         male              1962                        1964
# Captain America    male              1941                        1964
# Wolverine          male              1974                        1964
# Iron Man           male              1963                        1964
# Thor               male              1963                        1964
# Thing              male              1961                        1964
# Mister Fantastic   male              1961                        1964
# Hulk               male              1962                        1964
# Beast              male              1963                        1964
# Namor              male              1939                        1964
# Hawkeye            male              1964                        1964
# Daredevil          male              1964                        1964
# Doctor Strange     male              1963                        1964
# Hank Pym           male              1962                        1964
# Vision             male              1968                        1964
#
#                   years_since
# Name
# Spider-Man                 63
# Captain America            84
# Wolverine                  51
# Iron Man                   62
# Thor                       62
# Thing                      64
# Mister Fantastic           64
# Hulk                       63
# Beast                      62
# Namor                      86
# Hawkeye                    61
# Daredevil                  61
# Doctor Strange             62
# Hank Pym                   63
# Vision                     57

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with `first_appearance` after 1970

# %%
# your code goes here
mask=marvel_df['first_appearance']>1970
marvel_df[mask]
# Out:
#            Gender  first_appearance  (Vision, first_appearance)  years_since
# Name
# Wolverine    male              1974                        1964           51
# Storm      female              1975                        1964           50

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the female characters with `first_appearance` after 1970

# %%
# your code goes here
mask=(marvel_df['Gender']=='female') & (marvel_df['first_appearance']>1970)
marvel_df[mask]
# Out:
#        Gender  first_appearance  (Vision, first_appearance)  years_since
# Name
# Storm  female              1975                        1964           50

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame summary statistics

# %% [markdown]
# ### Show basic statistics of `marvel_df`

# %%
# your code goes here
marvel_df.head()
# Out:
#                 Gender  first_appearance  (Vision, first_appearance)  \
# Name
# Spider-Man        male              1962                        1964
# Captain America   male              1941                        1964
# Wolverine         male              1974                        1964
# Iron Man          male              1963                        1964
# Thor              male              1963                        1964
#
#                  years_since
# Name
# Spider-Man                63
# Captain America           84
# Wolverine                 51
# Iron Man                  62
# Thor                      62

# %%
marvel_df.describe()
# Out:
#        first_appearance  (Vision, first_appearance)  years_since
# count         20.000000                        20.0    20.000000
# mean        1961.850000                      1964.0    63.150000
# std            8.405982                         0.0     8.405982
# min         1939.000000                      1964.0    50.000000
# 25%         1961.750000                      1964.0    61.000000
# 50%         1963.000000                      1964.0    62.000000
# 75%         1964.000000                      1964.0    63.250000
# max         1975.000000                      1964.0    86.000000

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the mean value of `first_appearance`

# %%
# your code goes here
marvel_df.first_appearance.mean()
# Out:
# np.float64(1961.85)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the min value of `first_appearance`

# %%
# your code goes here
marvel_df.first_appearance.min()
# Out:
# np.int64(1939)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with the min value of `first_appearance`

# %%
# your code goes here
mask=marvel_df['first_appearance']== marvel_df.first_appearance.min()
marvel_df[mask]
# Out:
#       Gender  first_appearance  (Vision, first_appearance)  years_since
# Name
# Namor   male              1939                        1964           86

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame basic plottings

# %% [markdown]
# ### Reset index names of `marvel_df`

# %%
# your code goes here
marvel_df=marvel_df.reset_index()
marvel_df
# Out:
#                 Name  Gender  first_appearance  (Vision, first_appearance)  \
# 0         Spider-Man    male              1962                        1964
# 1    Captain America    male              1941                        1964
# 2          Wolverine    male              1974                        1964
# 3           Iron Man    male              1963                        1964
# 4               Thor    male              1963                        1964
# 5              Thing    male              1961                        1964
# 6   Mister Fantastic    male              1961                        1964
# 7               Hulk    male              1962                        1964
# 8              Beast    male              1963                        1964
# 9    Invisible Woman  female              1961                        1964
# 10             Storm  female              1975                        1964
# 11             Namor    male              1939                        1964
# 12           Hawkeye    male              1964                        1964
# 13         Daredevil    male              1964                        1964
# 14    Doctor Strange    male              1963                        1964
# 15          Hank Pym    male              1962                        1964
# 16     Scarlet Witch  female              1964                        1964
# 17              Wasp  female              1963                        1964
# 18       Black Widow  female              1964                        1964
# 19            Vision    male              1968                        1964
#
#     years_since
# 0            63
# 1            84
# 2            51
# 3            62
# 4            62
# 5            64
# 6            64
# 7            63
# 8            62
# 9            64
# 10           50
# 11           86
# 12           61
# 13           61
# 14           62
# 15           63
# 16           61
# 17           62
# 18           61
# 19           57

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot the values of `first_appearance`

# %%
# your code goes here
marvel_df.first_appearance.plot()
# Out:
# <Axes: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot a histogram (plot.hist) with values of `first_appearance`

# %%
plt.hist(marvel_df.first_appearance)
# Out:
# (array([ 2.,  0.,  0.,  0.,  0.,  0., 15.,  0.,  1.,  2.]),
#  array([1939. , 1942.6, 1946.2, 1949.8, 1953.4, 1957. , 1960.6, 1964.2,
#         1967.8, 1971.4, 1975. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
